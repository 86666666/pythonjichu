# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
s=pd.Series(np.arange(1,20,2))
s.plot()#plot方法集成在pandas中可以直接绘制折线图

# %%
da=pd.DataFrame(np.arange(20).reshape(4,5))
tu=da.plot()#plot方法集成在pandas中可以直接绘制折线图
print(tu)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#删除DataFrame中的数据
dt3={'城市':['北京','上海','广州','深圳','沈阳'],
    '环比':[101.5,101.2,101.3,102.0,100.1],
    '同比':[120.7,127.3,119.4,140.9,101.4],
    '定基':[121.4,127.8,120.0,145.5,101.6]}
a3=pd.DataFrame(dt3)
a3.plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29615 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27604 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22522 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
